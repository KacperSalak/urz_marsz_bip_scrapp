# %%
import sys
sys.path.insert(0, "..")

from build_df_from_json import build_combined_df

df = build_combined_df()
df
# Out:
#                       umw                                                url  \
# 0           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 1           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 2           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 3           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 4           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# ...                   ...                                                ...
# 2009  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_19...
# 2010  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_18...
# 2011  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_18...
# 2012  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_18...
# 2013  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_87...
#
#                                                   tytul  \
# 0     Decyzja Marszałka Województwa Łódzkiego z dnia...
# 1     Zakończenie oceny formalnej projektu „Budowa i...
# 2     Zakończenie oceny formalnej projektu „Rozwój k...
# 3     Postanowienie dotyczące decyzji Marszałka Woje...
# 4     Zakończenie oceny merytorycznej projektu „Budo...
# ...                                                 ...
# 2009  Uprawnienia właścicieli, użytkowników wieczyst...
# 2010  Ogłoszenie naboru ofert na wykonanie przez upr...
# 2011  Zapytanie ofertowe na realizację opracowania p...
# 2012  Plan Zrównoważonego Rozwoju Publicznego Transp...
# 2013  Ogłoszenie o zamiarze bezpośredniego zawarcia ...
#
#                                                   tresc  \
# 0     Decyzja Marszałka Województwa Łódzkiego z dnia...
# 1     Projekt „Budowa instalacji fotowoltaicznej na ...
# 2     Projekt „Rozwój kultury w Gminie Koluszki” zło...
# 3
# 4     Projekt „Budowa i modernizacja oświetlenia pub...
# ...                                                 ...
# 2009  I. Rodzaje uprawnień oraz tryb i termin dochod...
# 2010  Uchwała nr 994/15 Zarządu Województwa Wielkopo...
# 2011  Zapytanie ofertowe na realizację opracowania p...
# 2012  Aktualizacja Planu Zrównoważonego Rozwoju Publ...
# 2013  Ogłoszenie o zamiarze bezpośredniego zawarcia ...
#
#                                                att_text  \
# 0                   [ŚRIII.7222.59.2023.MS DECYZJA.pdf]
# 1                                                  None
# 2                                                  None
# 3     [GKIII.7440.8.2022.EK.AM - postanowienie + wyk...
# 4                                                  None
# ...                                                 ...
# 2009                                                NaN
# 2010                                                NaN
# 2011                                                NaN
# 2012                                                NaN
# 2013                                                NaN
#
#                                                att_link  att_list_len  \
# 0     [https://bip.lodzkie.pl/ogloszenia/komunikaty/...           1.0
# 1                                                  None           0.0
# 2                                                  None           0.0
# 3     [https://bip.lodzkie.pl/ogloszenia/komunikaty/...           1.0
# 4                                                  None           0.0
# ...                                                 ...           ...
# 2009                                                NaN           NaN
# 2010                                                NaN           NaN
# 2011                                                NaN           NaN
# 2012                                                NaN           NaN
# 2013                                                NaN           NaN
#
#                 data_pub            data_mod  view_cnt sub_tytul public_name
# 0    2023-06-29 00:00:00                 NaT      42.0       NaN         NaN
# 1    2023-06-28 00:00:00                 NaT      37.0       NaN         NaN
# 2    2023-06-28 00:00:00                 NaT      30.0       NaN         NaN
# 3    2023-06-27 00:00:00                 NaT      65.0       NaN         NaN
# 4    2023-06-27 00:00:00                 NaT      34.0       NaN         NaN
# ...                  ...                 ...       ...       ...         ...
# 2009 2016-04-18 09:22:42                 NaT       NaN       NaN         NaN
# 2010 2015-09-08 07:52:13                 NaT       NaN       NaN         NaN
# 2011 2015-07-24 08:12:46                 NaT       NaN       NaN         NaN
# 2012 2015-02-18 08:13:31 2020-12-03 13:27:07       NaN       NaN         NaN
# 2013 2014-12-19 16:56:08                 NaT       NaN       NaN         NaN
#
# [2014 rows x 12 columns]

# %%
import spacy 

nlp = spacy.load('pl_core_news_sm')

# %%
df['tresc'].iloc[0]
# Out:
# 'Decyzja Marszałka Województwa Łódzkiego z dnia 28 czerwca 2023 roku, znak: ŚRIII.7222.59.2023.MS w sprawie zmiany pozwolenia zintegrowanego '

# %%
doc = nlp(df['tresc'].iloc[0])

lemma_list = [token.pos_ for token in doc] 

print(lemma_list)

# for token in doc:
    # print(token.text, token.lemma_, token.pos_, token.is_stop)
# Out:
# ['NOUN', 'NOUN', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'ADJ', 'NOUN', 'ADJ', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'X', 'PUNCT', 'X', 'X', 'X', 'PUNCT', 'ADJ', 'PUNCT', 'PROPN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'ADJ']

# %%
from collections import Counter

counter = Counter(lemma_list)
# print(counter.most_common(1)[0][1])
print(counter.most_common(1)[0][1])
# Out:
# 10

# %%
import pandas as pd

cols_nlp = ("text", "lemma", "POS", "explain", "stopword")
rows_nlp = []

for t in doc:
    row = [t.text, t.lemma_, t.pos_, spacy.explain(t.pos_), t.is_stop]
    rows_nlp.append(row)

df_nlp = pd.DataFrame(rows_nlp, columns=cols_nlp)

print(df_nlp)
# Out:
#               text           lemma    POS      explain  stopword
# 0          Decyzja         decyzja   NOUN         noun     False
# 1        Marszałka       Marszałek   NOUN         noun     False
# 2      Województwa     Województwo   NOUN         noun     False
# 3        Łódzkiego       Łódzkiego    ADJ    adjective     False
# 4                z               z    ADP   adposition      True
# 5             dnia           dzień   NOUN         noun     False
# 6               28              28    ADJ    adjective     False
# 7          czerwca        czerwiec   NOUN         noun     False
# 8             2023            2023    ADJ    adjective     False
# 9             roku             rok   NOUN         noun      True
# 10               ,               ,  PUNCT  punctuation     False
# 11            znak            znak   NOUN         noun     False
# 12               :               :  PUNCT  punctuation     False
# 13           ŚRIII           ŚRIII      X        other     False
# 14               .               .  PUNCT  punctuation     False
# 15            7222            7222      X        other     False
# 16               .               .      X        other     False
# 17              59              59      X        other     False
# 18               .               .  PUNCT  punctuation     False
# 19            2023            2023    ADJ    adjective     False
# 20               .               .  PUNCT  punctuation     False
# 21              MS              MS  PROPN  proper noun     False
# 22               w               w    ADP   adposition      True
# 23         sprawie          sprawa   NOUN         noun     False
# 24          zmiany          zmiana   NOUN         noun     False
# 25      pozwolenia      pozwolenie   NOUN         noun     False
# 26  zintegrowanego  zintegrowanego    ADJ    adjective     False

# %%
df_nlp['POS'].value_counts().idxmax()
# Out:
# 'NOUN'

# %%
for index_all, row_all in df.iterrows():
    print(row_all)
    break
# Out:
# umw                                                 umw_lodzkiego
# url             https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# tytul           Decyzja Marszałka Województwa Łódzkiego z dnia...
# tresc           Decyzja Marszałka Województwa Łódzkiego z dnia...
# att_text                      [ŚRIII.7222.59.2023.MS DECYZJA.pdf]
# att_link        [https://bip.lodzkie.pl/ogloszenia/komunikaty/...
# att_list_len                                                  1.0
# data_pub                                      2023-06-29 00:00:00
# data_mod                                                      NaT
# view_cnt                                                     42.0
# sub_tytul                                                     NaN
# public_name                                                   NaN
# Name: 0, dtype: object

# %%
from collections import Counter

tmp_dict={}

for index_all, row_all in df.iterrows():
    try:
        doc = nlp(df['tresc'].iloc[index_all])

        words_list = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]        
        pos_list = [token.pos_ for token in doc if not token.is_stop and not token.is_punct] 

        counter_words = Counter(words_list)
        counter_pos = Counter(pos_list)

        
        tmp_dict[index_all] = {"most_com_wrd": counter_words.most_common(1)[0][0],
                               "most_com_wrd_cnt": counter_words.most_common(1)[0][1], 
                               "most_com_pos": counter_pos.most_common(1)[0][0],
                               "most_com_pos_cnt": counter_pos.most_common(1)[0][1]} 
    except:
        print(f'ERROR ON RECORD {index_all}')

tmp_df = pd.DataFrame(tmp_dict).T

nlp_df = pd.merge(df, tmp_df, left_index=True, right_index=True)
# Out:
# ERROR ON RECORD 3
# ERROR ON RECORD 5
# ERROR ON RECORD 8
# ERROR ON RECORD 29
# ERROR ON RECORD 47
# ERROR ON RECORD 51
# ERROR ON RECORD 60
# ERROR ON RECORD 61
# ERROR ON RECORD 63
# ERROR ON RECORD 65
# ERROR ON RECORD 66
# ERROR ON RECORD 67
# ERROR ON RECORD 76
# ERROR ON RECORD 77
# ERROR ON RECORD 78
# ERROR ON RECORD 91
# ERROR ON RECORD 149
# ERROR ON RECORD 180
# ERROR ON RECORD 238
# ERROR ON RECORD 240
# ERROR ON RECORD 241
# ERROR ON RECORD 369
# ERROR ON RECORD 414
# ERROR ON RECORD 452
# ERROR ON RECORD 453
# ERROR ON RECORD 461
# ERROR ON RECORD 464
# ERROR ON RECORD 466
# ERROR ON RECORD 491
# ERROR ON RECORD 492
# ERROR ON RECORD 493
# ERROR ON RECORD 494
# ERROR ON RECORD 495
# ERROR ON RECORD 517
# ERROR ON RECORD 518
# ERROR ON RECORD 519
# ERROR ON RECORD 520
# ERROR ON RECORD 523
# ERROR ON RECORD 541
# ERROR ON RECORD 542
# ERROR ON RECORD 545
# ERROR ON RECORD 546
# ERROR ON RECORD 547
# ERROR ON RECORD 548
# ERROR ON RECORD 549
# ERROR ON RECORD 550
# ERROR ON RECORD 551
# ERROR ON RECORD 553
# ERROR ON RECORD 554
# ERROR ON RECORD 555
# ERROR ON RECORD 556
# ERROR ON RECORD 557
# ERROR ON RECORD 558
# ERROR ON RECORD 560
# ERROR ON RECORD 564
# ERROR ON RECORD 568
# ERROR ON RECORD 569
# ERROR ON RECORD 570
# ERROR ON RECORD 571
# ERROR ON RECORD 572
# ERROR ON RECORD 573
# ERROR ON RECORD 574
# ERROR ON RECORD 575
# ERROR ON RECORD 576
# ERROR ON RECORD 579
# ERROR ON RECORD 580
# ERROR ON RECORD 581
# ERROR ON RECORD 583
# ERROR ON RECORD 591
# ERROR ON RECORD 599
# ERROR ON RECORD 600
# ERROR ON RECORD 604
# ERROR ON RECORD 608
# ERROR ON RECORD 609
# ERROR ON RECORD 610
# ERROR ON RECORD 611
# ERROR ON RECORD 613
# ERROR ON RECORD 615
# ERROR ON RECORD 616
# ERROR ON RECORD 617
# ERROR ON RECORD 618
# ERROR ON RECORD 621
# ERROR ON RECORD 624
# ERROR ON RECORD 625
# ERROR ON RECORD 633
# ERROR ON RECORD 635
# ERROR ON RECORD 636
# ERROR ON RECORD 641
# ERROR ON RECORD 663
# ERROR ON RECORD 664
# ERROR ON RECORD 668
# ERROR ON RECORD 671
# ERROR ON RECORD 672
# ERROR ON RECORD 674
# ERROR ON RECORD 679
# ERROR ON RECORD 681
# ERROR ON RECORD 682
# ERROR ON RECORD 683
# ERROR ON RECORD 684
# ERROR ON RECORD 685
# ERROR ON RECORD 687
# ERROR ON RECORD 688
# ERROR ON RECORD 690
# ERROR ON RECORD 697
# ERROR ON RECORD 698
# ERROR ON RECORD 704
# ERROR ON RECORD 706
# ERROR ON RECORD 709
# ERROR ON RECORD 710
# ERROR ON RECORD 719
# ERROR ON RECORD 721
# ERROR ON RECORD 723
# ERROR ON RECORD 724
# ERROR ON RECORD 727
# ERROR ON RECORD 729
# ERROR ON RECORD 730
# ERROR ON RECORD 732
# ERROR ON RECORD 734
# ERROR ON RECORD 735
# ERROR ON RECORD 736
# ERROR ON RECORD 738
# ERROR ON RECORD 739
# ERROR ON RECORD 740
# ERROR ON RECORD 743
# ERROR ON RECORD 746
# ERROR ON RECORD 748
# ERROR ON RECORD 750
# ERROR ON RECORD 751
# ERROR ON RECORD 753
# ERROR ON RECORD 754
# ERROR ON RECORD 755
# ERROR ON RECORD 763
# ERROR ON RECORD 765
# ERROR ON RECORD 771
# ERROR ON RECORD 773
# ERROR ON RECORD 774
# ERROR ON RECORD 775
# ERROR ON RECORD 776
# ERROR ON RECORD 777
# ERROR ON RECORD 778
# ERROR ON RECORD 779
# ERROR ON RECORD 780
# ERROR ON RECORD 781
# ERROR ON RECORD 782
# ERROR ON RECORD 784
# ERROR ON RECORD 785
# ERROR ON RECORD 786
# ERROR ON RECORD 787
# ERROR ON RECORD 788
# ERROR ON RECORD 789
# ERROR ON RECORD 791
# ERROR ON RECORD 794
# ERROR ON RECORD 795
# ERROR ON RECORD 796
# ERROR ON RECORD 797
# ERROR ON RECORD 798
# ERROR ON RECORD 801
# ERROR ON RECORD 802
# ERROR ON RECORD 803
# ERROR ON RECORD 804
# ERROR ON RECORD 805
# ERROR ON RECORD 807
# ERROR ON RECORD 809
# ERROR ON RECORD 810
# ERROR ON RECORD 811
# ERROR ON RECORD 815
# ERROR ON RECORD 820
# ERROR ON RECORD 825
# ERROR ON RECORD 838
# ERROR ON RECORD 846
# ERROR ON RECORD 856
# ERROR ON RECORD 857
# ERROR ON RECORD 862
# ERROR ON RECORD 864
# ERROR ON RECORD 866
# ERROR ON RECORD 867
# ERROR ON RECORD 868
# ERROR ON RECORD 870
# ERROR ON RECORD 871
# ERROR ON RECORD 873
# ERROR ON RECORD 874
# ERROR ON RECORD 875
# ERROR ON RECORD 1162
# ERROR ON RECORD 1172
# ERROR ON RECORD 1178
# ERROR ON RECORD 1183
# ERROR ON RECORD 1185
# ERROR ON RECORD 1186
# ERROR ON RECORD 1191
# ERROR ON RECORD 1194
# ERROR ON RECORD 1197
# ERROR ON RECORD 1198
# ERROR ON RECORD 1199
# ERROR ON RECORD 1200
# ERROR ON RECORD 1201
# ERROR ON RECORD 1204
# ERROR ON RECORD 1221
# ERROR ON RECORD 1223
# ERROR ON RECORD 1229
# ERROR ON RECORD 1230
# ERROR ON RECORD 1231
# ERROR ON RECORD 1232
# ERROR ON RECORD 1233
# ERROR ON RECORD 1234
# ERROR ON RECORD 1235
# ERROR ON RECORD 1236
# ERROR ON RECORD 1237
# ERROR ON RECORD 1238
# ERROR ON RECORD 1239
# ERROR ON RECORD 1240
# ERROR ON RECORD 1241
# ERROR ON RECORD 1242
# ERROR ON RECORD 1243
# ERROR ON RECORD 1244
# ERROR ON RECORD 1245
# ERROR ON RECORD 1246
# ERROR ON RECORD 1247
# ERROR ON RECORD 1248
# ERROR ON RECORD 1249
# ERROR ON RECORD 1250
# ERROR ON RECORD 1251
# ERROR ON RECORD 1252
# ERROR ON RECORD 1253
# ERROR ON RECORD 1255
# ERROR ON RECORD 1262
# ERROR ON RECORD 1279
# ERROR ON RECORD 1289
# ERROR ON RECORD 1290
# ERROR ON RECORD 1291
# ERROR ON RECORD 1292
# ERROR ON RECORD 1293
# ERROR ON RECORD 1305
# ERROR ON RECORD 1306
# ERROR ON RECORD 1308
# ERROR ON RECORD 1310
# ERROR ON RECORD 1311
# ERROR ON RECORD 1312
# ERROR ON RECORD 1313
# ERROR ON RECORD 1314
# ERROR ON RECORD 1354
# ERROR ON RECORD 1355
# ERROR ON RECORD 1356
# ERROR ON RECORD 1357
# ERROR ON RECORD 1359
# ERROR ON RECORD 1360
# ERROR ON RECORD 1361
# ERROR ON RECORD 1362
# ERROR ON RECORD 1363
# ERROR ON RECORD 1364
# ERROR ON RECORD 1365
# ERROR ON RECORD 1366
# ERROR ON RECORD 1367
# ERROR ON RECORD 1368
# ERROR ON RECORD 1369
# ERROR ON RECORD 1370
# ERROR ON RECORD 1406
# ERROR ON RECORD 1452
# ERROR ON RECORD 1453
# ERROR ON RECORD 1454
# ERROR ON RECORD 1455
# ERROR ON RECORD 1456
# ERROR ON RECORD 1457
# ERROR ON RECORD 1458
# ERROR ON RECORD 1459
# ERROR ON RECORD 1460
# ERROR ON RECORD 1469
# ERROR ON RECORD 1493
# ERROR ON RECORD 1519
# ERROR ON RECORD 1521
# ERROR ON RECORD 1522
# ERROR ON RECORD 1524
# ERROR ON RECORD 1545
# ERROR ON RECORD 1546
# ERROR ON RECORD 1547
# ERROR ON RECORD 1548
# ERROR ON RECORD 1549
# ERROR ON RECORD 1550
# ERROR ON RECORD 1551
# ERROR ON RECORD 1554
# ERROR ON RECORD 1555
# ERROR ON RECORD 1556
# ERROR ON RECORD 1559
# ERROR ON RECORD 1593
# ERROR ON RECORD 1774

# %%
nlp_df
# Out:
#                       umw                                                url  \
# 0           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 1           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 2           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 4           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# 6           umw_lodzkiego  https://bip.lodzkie.pl/ogloszenia/komunikaty/i...
# ...                   ...                                                ...
# 2009  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_19...
# 2010  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_18...
# 2011  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_18...
# 2012  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_18...
# 2013  umw_wielkopolskiego  https://bip.umww.pl/292---k_332---k_287---k_87...
#
#                                                   tytul  \
# 0     Decyzja Marszałka Województwa Łódzkiego z dnia...
# 1     Zakończenie oceny formalnej projektu „Budowa i...
# 2     Zakończenie oceny formalnej projektu „Rozwój k...
# 4     Zakończenie oceny merytorycznej projektu „Budo...
# 6     Obwieszczenie o wydanej dla ZGO AQUARIUM Sp. z...
# ...                                                 ...
# 2009  Uprawnienia właścicieli, użytkowników wieczyst...
# 2010  Ogłoszenie naboru ofert na wykonanie przez upr...
# 2011  Zapytanie ofertowe na realizację opracowania p...
# 2012  Plan Zrównoważonego Rozwoju Publicznego Transp...
# 2013  Ogłoszenie o zamiarze bezpośredniego zawarcia ...
#
#                                                   tresc  \
# 0     Decyzja Marszałka Województwa Łódzkiego z dnia...
# 1     Projekt „Budowa instalacji fotowoltaicznej na ...
# 2     Projekt „Rozwój kultury w Gminie Koluszki” zło...
# 4     Projekt „Budowa i modernizacja oświetlenia pub...
# 6     Obwieszczenie o wydanej dla ZGO AQUARIUM Sp. z...
# ...                                                 ...
# 2009  I. Rodzaje uprawnień oraz tryb i termin dochod...
# 2010  Uchwała nr 994/15 Zarządu Województwa Wielkopo...
# 2011  Zapytanie ofertowe na realizację opracowania p...
# 2012  Aktualizacja Planu Zrównoważonego Rozwoju Publ...
# 2013  Ogłoszenie o zamiarze bezpośredniego zawarcia ...
#
#                                         att_text  \
# 0            [ŚRIII.7222.59.2023.MS DECYZJA.pdf]
# 1                                           None
# 2                                           None
# 4                                           None
# 6     [obwieszczenie ŚRIII.7222.128.2022.ML.pdf]
# ...                                          ...
# 2009                                         NaN
# 2010                                         NaN
# 2011                                         NaN
# 2012                                         NaN
# 2013                                         NaN
#
#                                                att_link  att_list_len  \
# 0     [https://bip.lodzkie.pl/ogloszenia/komunikaty/...           1.0
# 1                                                  None           0.0
# 2                                                  None           0.0
# 4                                                  None           0.0
# 6     [https://bip.lodzkie.pl/ogloszenia/komunikaty/...           1.0
# ...                                                 ...           ...
# 2009                                                NaN           NaN
# 2010                                                NaN           NaN
# 2011                                                NaN           NaN
# 2012                                                NaN           NaN
# 2013                                                NaN           NaN
#
#                 data_pub            data_mod  view_cnt sub_tytul public_name  \
# 0    2023-06-29 00:00:00                 NaT      42.0       NaN         NaN
# 1    2023-06-28 00:00:00                 NaT      37.0       NaN         NaN
# 2    2023-06-28 00:00:00                 NaT      30.0       NaN         NaN
# 4    2023-06-27 00:00:00                 NaT      34.0       NaN         NaN
# 6    2023-06-26 00:00:00                 NaT      17.0       NaN         NaN
# ...                  ...                 ...       ...       ...         ...
# 2009 2016-04-18 09:22:42                 NaT       NaN       NaN         NaN
# 2010 2015-09-08 07:52:13                 NaT       NaN       NaN         NaN
# 2011 2015-07-24 08:12:46                 NaT       NaN       NaN         NaN
# 2012 2015-02-18 08:13:31 2020-12-03 13:27:07       NaN       NaN         NaN
# 2013 2014-12-19 16:56:08                 NaT       NaN       NaN         NaN
#
#       most_com_wrd most_com_wrd_cnt most_com_pos most_com_pos_cnt
# 0             2023                2         NOUN                9
# 1               01                2         NOUN               14
# 2            Gmina                2         NOUN               11
# 4               03                2         NOUN               16
# 6     obwieszczeni                1         NOUN               11
# ...            ...              ...          ...              ...
# 2009  nieruchomość               11         NOUN              265
# 2010          2015                3         NOUN               15
# 2011      ofertowy                2         NOUN               14
# 2012           rok               10         NOUN              150
# 2013    ogłoszenie                1         NOUN                8
#
# [1730 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
keys = nlp_df.umw.unique()
data = [len(nlp_df[nlp_df.umw == key]) for key in keys]

# palette_color = sns.color_palette('RdBu')
# palette_color = sns.color_palette('bright')
palette_color = sns.color_palette('viridis')

plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')

plt.title('N=1730',
            fontsize='medium',
            loc='center',
            style='normal',
            family='monospace')

plt.suptitle(f'Udział danego UMW, w pełnym zbiorze komunikatów (po oczyszczeniu)', fontsize='large', fontweight='bold')

plt.show()

# %%
nlp_df1 = nlp_df.loc[nlp_df['umw'] == 'umw_lodzkiego']

# len(nlp_df1.most_com_wrd.unique().tolist())
nlp_df1.duplicated('most_com_wrd')
# Out:
# 0      False
# 1      False
# 2      False
# 4      False
# 6      False
#        ...
# 445     True
# 446     True
# 447     True
# 448    False
# 449     True
# Length: 427, dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(30, 6))

sns.countplot(x=nlp_df1['most_com_wrd'], order=nlp_df1['most_com_wrd'].value_counts().index)

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.grid()
plt.show()

# %%
for i in nlp_df.umw.unique().tolist():
    tmp_df = nlp_df[nlp_df["umw"] == i]

    palette_color = sns.color_palette('viridis')

    plt.figure(figsize=(30, 6))

    sns.countplot(x=tmp_df['most_com_wrd'], order=tmp_df['most_com_wrd'].value_counts().iloc[:8].index, palette=palette_color)

    plt.xticks(rotation=45, ha='right')

    plt.title(f"N={len(tmp_df['most_com_wrd'])}",
            fontsize='medium',
            loc='center',
            style='normal',
            family='monospace')

    plt.suptitle(f'8 najczęściej występujących w komunikatach słów dla ogłoszeń pochdzących z danego województwa - {i}', fontsize='large', fontweight='bold')
    
    plt.tight_layout()
    plt.grid()
    plt.show()
